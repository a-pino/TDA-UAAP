# %% [markdown]
# # Data Preprocessing and Dimensionality Reduction
#
# ## Source material
#
# /TDA-NBA/notebooks/DimReduction
#
# ## Basketball Positions
#
# Our source dataset has the following positions:
#
# * **Guard (G)**
# * **Forward (F)**
# * **Center (C)**
#
# ## Feature Definitions - Recommendations
#
# NAME -
# GP - keep as is
# MIN	- keep as is
# MPG - remove (redunant with total min)
# STARTS	- keep as is
# 3PT FGs M/A - split to 3FGM, 3FGA
# 3PT FGs % - remove (redundant)
# 2PT FGs M/A	- split to 2FGM, 2FGA
# 2PT FGs % - remove (redundant)
# FGs %	- remove (redundant)
# DEFENDED M/A - split to DFGM, DFGA
# DEFENDED %	- remove (redundant)
# OPEN M/A - split to OFGM, OFGA
# OPEN %	- remove (redundant)
# FTs M/A	- split to FTM, FTA
# FTs % - remove (redundant)
# HI	- rename to HIGH_SCORE
# LO	- rename to LOW_SCORE
# DEF REBOUNDS - rename to DREB
# OFF REBOUNDS - rename to OREB, add REB
# AST
# STL
# BLK
# OFF TOs	- rename to OFF_FOUL
# DEF TOs	- rename to DEF_FOUL
# TECH - rename to TECH_FOUL
# UF	- rename to UF_FOUL
# TOTAL- rename to TOTAL_FOUL
# +/- - rename to PLUS_MINUS
# ## Importing Data

# %%
import pandas as pd
import numpy as np
import os
print(os.getcwd())

# import libraries for visualization
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pylab

#import libraries for features decomposition
import sklearn as sk
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA
# Out:
# /run/media/sandrone/Common Sky/TDA-UAAP/Notebooks

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
#import data
df = pd.read_csv('/run/media/sandrone/Common Sky/TDA-UAAP/Data/stats_full.csv')
print("(rows,cols) =",df.shape)


df.head()
# Out:
# (rows,cols) = (129, 46)
#    Number             Name  Team Position   PPG   RPG  APG  SPG  BPG  TOPG  \
# 0      10  Ildefonso, Dave  ADMU        G  12.0   8.3  2.7  1.0  0.1   2.8
# 1      34     Kouame, Ange  ADMU        C  11.6  11.3  1.7  0.5  2.5   1.4
# 2       2   Andrade, Bryan  ADMU        G   9.5   2.7  2.1  0.9  0.2   1.5
# 3       6      Koon, Chris  ADMU        G   6.3   3.4  1.9  0.7  0.1   1.3
# 4      13     Gomez, Vince  ADMU        G   3.4   0.7  2.0  0.5  0.0   1.3
#
#    FPG  FDPG  +/-  EFFPG     FG%    3PT%     FT%  MPG_x            NAME  GP  \
# 0  1.7   2.3  7.7   13.5  30.90%  25.90%  62.00%  27.44  Dave Ildefonso  14
# 1  2.4   3.9  8.7   24.7  54.80%  43.80%  52.70%  27.30     Ange Kouame  14
# 2  1.5   1.8  9.9   10.3  36.20%  34.70%  92.60%  25.50   Bryan Andrade  14
# 3  1.2   1.5  2.7    9.2  40.80%  30.60%  70.80%  16.21      Chris Koon  14
# 4  1.2   1.0 -1.1    3.4  30.60%  29.70%  50.00%  14.15     Vince Gomez  12
#
# ...

# %%
pos_labels = df['Position']

# %%
# Assign position numeric label (but should it be a sparse matrix?)
dict = {'G': 0, 'F': 1, 'C' : 2}

pos_labels.replace(dict).head()
# Out:
# 0    0.0
# 1    2.0
# 2    0.0
# 3    0.0
# 4    0.0
# Name: Position, dtype: float64
